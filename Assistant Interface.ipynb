# %%
# Import the functions or classes from the Python script
from Your_Assistant import voice_based_virtual_assistant

import pandas as pd

# Your_Assistant= voice_based_virtual_assistant

Classification = {
    'Precision': {
        'get_news': 1.0,
        'get_weather': 0.80,
        'greeting': 1.00,
        'joke': 1.00,
        'leaving': 1.00,
        'search_google': 1.00,
        'search_youtube': 0.60,
        'time': 1.00,
        'accuracy':0.83,
        'weight_avg':0.83
    },
    'Recall': {
        'get_news': 1.0,
        'get_weather': 1.00,
        'greeting': 1.00,
        'joke': 1.00,
        'leaving': 1.00,
        'search_google': 0.86,
        'search_youtube': 1.00,
        'time': 0.75,
        'accuracy':0.70,
        'weight_avg':0.87
    },
    'F1-score': {
        'get_news': 1.0,
        'get_weather': 0.89,
        'greeting': 1.00,
        'joke': 1.00,
        'leaving': 1.00,
        'search_google': 0.92,
        'search_youtube': 0.75,
        'time': 0.86,
        'accuracy':0.90,
        'weight_avg':0.80
    },
    'Support': {
        'get_news': 2,
        'get_weather': 12,
        'greeting': 3,
        'joke': 3,
        'leaving': 1,
        'search_google': 7,
        'search_youtube': 3,
        'time': 4,
        'accuracy':0.83,
        'weight_avg':0.82
    },

    
}

Accuracy=0.89

print(f'Our Assistant Accuracy is {Accuracy}')

# %%
classify= pd.DataFrame(Classification)
classify
# Out:
#                 Precision  Recall  F1-score  Support
# get_news             1.00    1.00      1.00     2.00
# get_weather          0.80    1.00      0.89    12.00
# greeting             1.00    1.00      1.00     3.00
# joke                 1.00    1.00      1.00     3.00
# leaving              1.00    1.00      1.00     1.00
# search_google        1.00    0.86      0.92     7.00
# search_youtube       0.60    1.00      0.75     3.00
# time                 1.00    0.75      0.86     4.00
# accuracy             0.83    0.70      0.90     0.83
# weight_avg           0.83    0.87      0.80     0.82

# %%
from IPython.display import Image

# Set the desired width and height
width = 950
height = 2

# Create the Image object with the specified width and height
a=Image(filename='Virtual.jpg', width=width, height=height)
a

# %%
Your_assistant=voice_based_virtual_assistant()
Your_assistant
# Out:
# Hello there! Im Your Virtual Assistant ready to assist you. How can I help you today?
# Enter your text: tell me news in india
# Predicted Intent: get_news
# 1. Cyclone Remal Live Updates: Bengal, Bangladesh on high alert, Tripura issues advisory amid cyclonic storm forecast | Today News - Mint
# 2. NASA Launches Tiny Climate Change Satellite To Study Earth's Poles - NDTV
# 3. Lok Sabha Election 2024 LIVE: Voting concludes for 486 out of 543 seats - Hindustan Times
#
# Enter your text: open google
# Predicted Intent: search_google
# Listening.....
# Recognizing....
# user said:Hindi movies
#
# Enter your text: tell me about weather in mumbai
# Predicted Intent: get_weather
# The current weather in mumbai is mist with a temperature of 304.14°C and humidity of 79%.
